# %%
import sklearn as sk
import pandas as pd

# %%
df = pd.read_csv("./data/kp/set1.csv", dtype={"Generacion": int, "Numero de nodos": int, "Numero de funciones":int, "Numero de terminales":int, 
                                                 "Iteraciones Promedio DoWhile":int, "Profundidad":int, "Terminal Agregar":int, "Terminal Eliminar":int, "Terminal Mejora":int,
                                                 "ErrorRelativoPromedio":float,"Fitness":float,"Tiempo de Ejecucion Promedio(ms)":float })

# %%
X = df.drop(['score_aceptabilidad'], axis=1)
display(X)
# Out:
#         Generacion   Numero de nodos   Numero de funciones  \
# 0                0                13                     7
# 1                0                52                    29
# 2                0                 3                     1
# 3                0                 6                     3
# 4                0                 3                     1
# ...            ...               ...                   ...
# 124980         249               149                    79
# 124981         249               156                    82
# 124982         249               185                    99
# 124983         249               185                    99
# 124984         249               127                    69
#
#          Numero de terminales   Iteraciones Promedio DoWhile   Profundidad  \
# 0                           6                              0             4
# 1                          23                              0             6
# 2                           2                              0             2
# 3                           3                            200             3
# 4                           2                            200             2
# ...                       ...                            ...           ...
# 124980                     70                            400            10
# 124981                     74                            400            10
# 124982                     86                            400            10
# 124983                     86                            400            10
# 124984                     58                            400            10
#
#          Terminal Agregar   Terminal Eliminar   Terminal Mejora
# 0                       1                   2                 0
# 1                      14                   5                 0
# 2                       0                   1                 0
# 3                       2                   0                 1
# 4                       1                   1                 0
# ...                   ...                 ...               ...
# 124980                 36                   8                15
# 124981                 34                   9                18
# 124982                 45                   9                19
# 124983                 45                   9                19
# 124984                 31                   5                14
#
# [124985 rows x 9 columns]

# %%
Y = df['score_aceptabilidad']
display(Y)
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 124980    0
# 124981    0
# 124982    0
# 124983    0
# 124984    0
# Name: score_aceptabilidad, Length: 124985, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.25, random_state=16)

# %%
x_train
# Out:
#         Generacion   Numero de nodos   Numero de funciones  \
# 8843            17                38                    20
# 11369           22                50                    27
# 7624            15                44                    23
# 74130          148               158                    83
# 39927           79               147                    77
# ...            ...               ...                   ...
# 50497          100                95                    49
# 98885          197               162                    86
# 2169             4                32                    16
# 113902         227               181                    98
# 105129         210               176                    92
#
#          Numero de terminales   Iteraciones Promedio DoWhile   Profundidad  \
# 8843                       18                            200             8
# 11369                      23                            200            10
# 7624                       21                            400             8
# 74130                      75                            400            10
# 39927                      70                            400            10
# ...                       ...                            ...           ...
# 50497                      46                            400            10
# 98885                      76                            400            10
# 2169                       16                            800             5
# 113902                     83                            400            10
# 105129                     84                            400            10
#
#          Terminal Agregar   Terminal Eliminar   Terminal Mejora
# 8843                    6                   1                 5
# 11369                  11                   1                 5
# 7624                   12                   0                 3
# 74130                  35                   8                17
# 39927                  31                   4                17
# ...                   ...                 ...               ...
# 50497                  16                   4                13
# 98885                  35                   8                20
# 2169                   10                   3                 1
# 113902                 42                   8                20
# 105129                 39                   5                22
#
# [93738 rows x 9 columns]

# %%
from sklearn.preprocessing import StandardScaler
escalar = StandardScaler()
x_train = escalar.fit_transform(x_train)
x_test = escalar.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

algoritmo = LogisticRegression(random_state=16)

# %%
algoritmo.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=16)

# %%
y_pred = algoritmo.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix

matriz = confusion_matrix(y_test, y_pred)

# %%
print(matriz)
# Out:
# [[21584   677]
#  [ 2499  6487]]

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred)
print(precision)
# Out:
# 0.905499720826354

# %%
from sklearn.metrics import accuracy_score

exactitud = accuracy_score(y_test, y_pred)
print(exactitud)
# Out:
# 0.8983582423912696

# %%
from sklearn.metrics import recall_score

recall = recall_score(y_test, y_pred)
print(recall)
# Out:
# 0.7219007344758513

# %%
from sklearn.metrics import f1_score

f1 = f1_score(y_test, y_pred)
print(f1)
# Out:
# 0.803343653250774

# %%
df = pd.read_csv("./data/kp/set4.csv", dtype={"Generacion": int, "Numero de nodos": int, "Numero de funciones":int, "Numero de terminales":int, 
                                                 "Iteraciones Promedio DoWhile":int, "Profundidad":int, "Terminal Agregar":int, "Terminal Eliminar":int, "Terminal Mejora":int,
                                                 "ErrorRelativoPromedio":float,"Fitness":float,"Tiempo de Ejecucion Promedio(ms)":float })

X2 = df.drop(['score_aceptabilidad'], axis=1)
Y2 = Y = df['score_aceptabilidad']

# %%
x2_train, x2_test, y2_train, y2_test = train_test_split(X2,Y2,test_size=0.99, random_state=16)

# %%
x2_test = escalar.transform(x2_test)

# %%
test_pred = algoritmo.predict(x2_test)
test_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
matriz2 = confusion_matrix(y2_test, test_pred)
precision2 = precision_score(y2_test, test_pred)
exactitud2 = accuracy_score(y2_test, test_pred)
print("Matriz de Confusion: ")
print(matriz2)
print("Precision: ")
print(precision2)
print("Exactitud: ")
print(exactitud2)
# Out:
# Matriz de Confusion:
# [[102390   2258]
#  [ 22954  23973]]
# Precision:
# 0.9139186458770158
# Exactitud:
# 0.8336665017318159
